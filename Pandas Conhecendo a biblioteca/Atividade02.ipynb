# %% [markdown]
# ## Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar algumas análises utilizando um arquivo csv diferente: alunos.csv.
#
# 1) Calcular a média de quartos dos imóveis;
#
# 2) Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
import pandas as pd

# %%
# Importação de dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'

dados = pd.read_csv(url, sep = ';')

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados.groupby('Tipo')[['Quartos']].mean().sort_values('Quartos', ascending= False)
# Out:
#                                Quartos
# Tipo
# Hotel                        25.500000
# Pousada/Chalé                23.000000
# Sítio                         5.100000
# Casa de Condomínio            4.007028
# Casa                          3.133402
# Chácara                       3.000000
# Apartamento                   2.481569
# Casa de Vila                  1.927711
# Casa Comercial                1.562264
# Flat                          1.415966
# Loft                          1.117647
# Quitinete                     0.834928
# Studio                        0.500000
# Prédio Inteiro                0.335548
# Box/Garagem                   0.060976
# Loja Shopping/ Ct Comercial   0.044534
# Galpão/Depósito/Armazém       0.043339
# Terreno Padrão                0.042857
# Conjunto Comercial/Sala       0.040939
# Loja/Salão                    0.010519
# Indústria                     0.000000
# Loteamento/Condomínio         0.000000

# %%
len(dados.Bairro.unique())
# Out:
# 162

# %%
df = dados.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending= False)
df
# Out:
#                           Valor
# Bairro
# Jacarepaguá       314143.489637
# Irajá             154610.470588
# Caju              120264.782609
# Vasco da Gama     120000.000000
# Cidade Nova        88166.692308
# ...                         ...
# Inhoaíba             738.888889
# Turiaçu              733.333333
# Magalhães Bastos     726.666667
# Santíssimo           709.090909
# Senador Camará       635.000000
#
# [162 rows x 1 columns]

# %%
df.head(5).plot(
        kind = 'bar',
        figsize= (12,8),
        title = 'Valor por bairro',
        xlabel= 'Bairro', 
        ylabel= 'Média de valor',
        color = 'Purple')
# Out:
# <Axes: title={'center': 'Valor por bairro'}, xlabel='Bairro', ylabel='Média de valor'>
